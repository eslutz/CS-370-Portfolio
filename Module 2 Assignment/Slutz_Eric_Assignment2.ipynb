# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam
from keras.utils import np_utils

np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # of number of outputs = number digits
OPTIMIZER = SGD() # optimizer
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in sets 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test,
                       Y_test,
                       verbose=VERBOSE)

print("Original Run: 'N_HIDDEN' =", N_HIDDEN)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_37 (Dense)            (None, 128)               100480
#
#  activation_37 (Activation)  (None, 128)               0
#
#  dense_38 (Dense)            (None, 128)               16512
#
#  activation_38 (Activation)  (None, 128)               0
#
#  dense_39 (Dense)            (None, 10)                1290
#
#  activation_39 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
#   4/375 [..............................] - ETA: 6s - loss: 2.3152 - accuracy: 0.0859
# 2023-03-11 16:37:34.348066: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 371/375 [============================>.] - ETA: 0s - loss: 1.4266 - accuracy: 0.6406
# 2023-03-11 16:37:38.290624: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 5s 12ms/step - loss: 1.4194 - accuracy: 0.6426 - val_loss: 0.7110 - val_accuracy: 0.8430
# Epoch 2/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.5829 - accuracy: 0.8539 - val_loss: 0.4452 - val_accuracy: 0.8841
# Epoch 3/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.4349 - accuracy: 0.8833 - val_loss: 0.3700 - val_accuracy: 0.8982
# Epoch 4/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3779 - accuracy: 0.8952 - val_loss: 0.3328 - val_accuracy: 0.9076
# Epoch 5/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3452 - accuracy: 0.9029 - val_loss: 0.3090 - val_accuracy: 0.9135
# Epoch 6/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.3224 - accuracy: 0.9089 - val_loss: 0.2930 - val_accuracy: 0.9182
# Epoch 7/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.3051 - accuracy: 0.9137 - val_loss: 0.2793 - val_accuracy: 0.9213
# Epoch 8/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2907 - accuracy: 0.9178 - val_loss: 0.2680 - val_accuracy: 0.9249
# Epoch 9/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2785 - accuracy: 0.9212 - val_loss: 0.2587 - val_accuracy: 0.9283
# Epoch 10/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2678 - accuracy: 0.9242 - val_loss: 0.2493 - val_accuracy: 0.9305
# Epoch 11/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2580 - accuracy: 0.9270 - val_loss: 0.2426 - val_accuracy: 0.9322
# Epoch 12/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2495 - accuracy: 0.9289 - val_loss: 0.2347 - val_accuracy: 0.9337
# Epoch 13/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2416 - accuracy: 0.9316 - val_loss: 0.2289 - val_accuracy: 0.9350
# Epoch 14/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2339 - accuracy: 0.9340 - val_loss: 0.2234 - val_accuracy: 0.9373
# Epoch 15/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2269 - accuracy: 0.9360 - val_loss: 0.2174 - val_accuracy: 0.9377
# Epoch 16/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2203 - accuracy: 0.9380 - val_loss: 0.2118 - val_accuracy: 0.9403
# Epoch 17/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2140 - accuracy: 0.9397 - val_loss: 0.2077 - val_accuracy: 0.9413
# Epoch 18/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2080 - accuracy: 0.9409 - val_loss: 0.2035 - val_accuracy: 0.9418
# Epoch 19/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2025 - accuracy: 0.9424 - val_loss: 0.2006 - val_accuracy: 0.9445
# Epoch 20/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1972 - accuracy: 0.9441 - val_loss: 0.1936 - val_accuracy: 0.9453
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1957 - accuracy: 0.9439
# Original Run: 'N_HIDDEN' = 128
# Test score: 0.1956627368927002
# Test accuracy: 0.9439000487327576

# %%
np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # of number of outputs = number digits
OPTIMIZER = SGD() # optimizer
N_HIDDEN = 1
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in sets 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test,
                       Y_test,
                       verbose=VERBOSE)

print("Updated Parameter Run 1: 'N_HIDDEN' =", N_HIDDEN)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 1)                 785
#
#  activation_13 (Activation)  (None, 1)                 0
#
#  dense_14 (Dense)            (None, 1)                 2
#
#  activation_14 (Activation)  (None, 1)                 0
#
#  dense_15 (Dense)            (None, 10)                20
#
#  activation_15 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 807
# Trainable params: 807
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2023-03-11 14:30:38.940005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 371/375 [============================>.] - ETA: 0s - loss: 2.1762 - accuracy: 0.1744
# 2023-03-11 14:30:43.227532: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 5s 12ms/step - loss: 2.1751 - accuracy: 0.1749 - val_loss: 2.0870 - val_accuracy: 0.2045
# Epoch 2/20
# 375/375 [==============================] - 4s 11ms/step - loss: 2.0438 - accuracy: 0.1996 - val_loss: 1.9986 - val_accuracy: 0.2039
# Epoch 3/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.9752 - accuracy: 0.2064 - val_loss: 1.9443 - val_accuracy: 0.2197
# Epoch 4/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.9289 - accuracy: 0.2232 - val_loss: 1.9034 - val_accuracy: 0.2239
# Epoch 5/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.8929 - accuracy: 0.2394 - val_loss: 1.8695 - val_accuracy: 0.2393
# Epoch 6/20
# 375/375 [==============================] - 4s 11ms/step - loss: 1.8621 - accuracy: 0.2529 - val_loss: 1.8408 - val_accuracy: 0.2488
# Epoch 7/20
# 375/375 [==============================] - 4s 11ms/step - loss: 1.8352 - accuracy: 0.2648 - val_loss: 1.8137 - val_accuracy: 0.2695
# Epoch 8/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.8114 - accuracy: 0.2740 - val_loss: 1.7907 - val_accuracy: 0.2752
# Epoch 9/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.7911 - accuracy: 0.2789 - val_loss: 1.7723 - val_accuracy: 0.2749
# Epoch 10/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.7741 - accuracy: 0.2840 - val_loss: 1.7547 - val_accuracy: 0.2837
# Epoch 11/20
# 375/375 [==============================] - 5s 12ms/step - loss: 1.7596 - accuracy: 0.2877 - val_loss: 1.7410 - val_accuracy: 0.2923
# Epoch 12/20
# 375/375 [==============================] - 8s 22ms/step - loss: 1.7471 - accuracy: 0.2906 - val_loss: 1.7287 - val_accuracy: 0.2842
# Epoch 13/20
# 375/375 [==============================] - 7s 20ms/step - loss: 1.7363 - accuracy: 0.2930 - val_loss: 1.7178 - val_accuracy: 0.2941
# Epoch 14/20
# 375/375 [==============================] - 4s 11ms/step - loss: 1.7271 - accuracy: 0.2943 - val_loss: 1.7095 - val_accuracy: 0.2936
# Epoch 15/20
# 375/375 [==============================] - 4s 11ms/step - loss: 1.7188 - accuracy: 0.2950 - val_loss: 1.7015 - val_accuracy: 0.2949
# Epoch 16/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.7117 - accuracy: 0.2977 - val_loss: 1.6937 - val_accuracy: 0.2943
# Epoch 17/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.7054 - accuracy: 0.2975 - val_loss: 1.6869 - val_accuracy: 0.2987
# Epoch 18/20
# 375/375 [==============================] - 4s 11ms/step - loss: 1.6996 - accuracy: 0.2996 - val_loss: 1.6815 - val_accuracy: 0.2965
# Epoch 19/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.6942 - accuracy: 0.3008 - val_loss: 1.6759 - val_accuracy: 0.3001
# Epoch 20/20
# 375/375 [==============================] - 4s 10ms/step - loss: 1.6896 - accuracy: 0.3006 - val_loss: 1.6716 - val_accuracy: 0.2964
# 313/313 [==============================] - 3s 9ms/step - loss: 1.6931 - accuracy: 0.2996
# Updated Parameter Run 1: 'N_HIDDEN' = 1
# Test score: 1.6931358575820923
# Test accuracy: 0.2996000051498413

# %%
np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # of number of outputs = number digits
OPTIMIZER = SGD() # optimizer
N_HIDDEN = 64
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in sets 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test,
                       Y_test,
                       verbose=VERBOSE)

print("Updated Parameter Run 2: 'N_HIDDEN' =", N_HIDDEN)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 64)                50240
#
#  activation_16 (Activation)  (None, 64)                0
#
#  dense_17 (Dense)            (None, 64)                4160
#
#  activation_17 (Activation)  (None, 64)                0
#
#  dense_18 (Dense)            (None, 10)                650
#
#  activation_18 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2023-03-11 14:32:10.811535: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 371/375 [============================>.] - ETA: 0s - loss: 1.5437 - accuracy: 0.5538
# 2023-03-11 14:32:14.863765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 5s 13ms/step - loss: 1.5360 - accuracy: 0.5566 - val_loss: 0.7924 - val_accuracy: 0.8284
# Epoch 2/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.6179 - accuracy: 0.8475 - val_loss: 0.4715 - val_accuracy: 0.8807
# Epoch 3/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.4495 - accuracy: 0.8794 - val_loss: 0.3897 - val_accuracy: 0.8938
# Epoch 4/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.3893 - accuracy: 0.8926 - val_loss: 0.3515 - val_accuracy: 0.9012
# Epoch 5/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3567 - accuracy: 0.8992 - val_loss: 0.3278 - val_accuracy: 0.9077
# Epoch 6/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.3353 - accuracy: 0.9043 - val_loss: 0.3108 - val_accuracy: 0.9124
# Epoch 7/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.3187 - accuracy: 0.9090 - val_loss: 0.2991 - val_accuracy: 0.9157
# Epoch 8/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3052 - accuracy: 0.9121 - val_loss: 0.2889 - val_accuracy: 0.9177
# Epoch 9/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2938 - accuracy: 0.9157 - val_loss: 0.2778 - val_accuracy: 0.9205
# Epoch 10/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2835 - accuracy: 0.9186 - val_loss: 0.2704 - val_accuracy: 0.9225
# Epoch 11/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2744 - accuracy: 0.9207 - val_loss: 0.2629 - val_accuracy: 0.9237
# Epoch 12/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2657 - accuracy: 0.9234 - val_loss: 0.2564 - val_accuracy: 0.9258
# Epoch 13/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2576 - accuracy: 0.9261 - val_loss: 0.2503 - val_accuracy: 0.9271
# Epoch 14/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2504 - accuracy: 0.9277 - val_loss: 0.2430 - val_accuracy: 0.9307
# Epoch 15/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2432 - accuracy: 0.9297 - val_loss: 0.2376 - val_accuracy: 0.9320
# Epoch 16/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2367 - accuracy: 0.9319 - val_loss: 0.2322 - val_accuracy: 0.9337
# Epoch 17/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2302 - accuracy: 0.9337 - val_loss: 0.2265 - val_accuracy: 0.9342
# Epoch 18/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2242 - accuracy: 0.9350 - val_loss: 0.2215 - val_accuracy: 0.9377
# Epoch 19/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2187 - accuracy: 0.9366 - val_loss: 0.2165 - val_accuracy: 0.9394
# Epoch 20/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2132 - accuracy: 0.9381 - val_loss: 0.2120 - val_accuracy: 0.9411
# 313/313 [==============================] - 3s 9ms/step - loss: 0.2124 - accuracy: 0.9401
# Updated Parameter Run 2: 'N_HIDDEN' = 64
# Test score: 0.2123962938785553
# Test accuracy: 0.9401000738143921

# %%
np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # of number of outputs = number digits
OPTIMIZER = SGD() # optimizer
N_HIDDEN = 256
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in sets 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test,
                       Y_test,
                       verbose=VERBOSE)

print("Updated Parameter Run 3: 'N_HIDDEN' =", N_HIDDEN)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 256)               200960
#
#  activation_19 (Activation)  (None, 256)               0
#
#  dense_20 (Dense)            (None, 256)               65792
#
#  activation_20 (Activation)  (None, 256)               0
#
#  dense_21 (Dense)            (None, 10)                2570
#
#  activation_21 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
#   1/375 [..............................] - ETA: 1:38 - loss: 2.3505 - accuracy: 0.1094
# 2023-03-11 14:33:34.128786: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 372/375 [============================>.] - ETA: 0s - loss: 1.3576 - accuracy: 0.6924
# 2023-03-11 14:33:37.624653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 4s 11ms/step - loss: 1.3522 - accuracy: 0.6937 - val_loss: 0.6556 - val_accuracy: 0.8612
# Epoch 2/20
# 375/375 [==============================] - 5s 13ms/step - loss: 0.5385 - accuracy: 0.8685 - val_loss: 0.4169 - val_accuracy: 0.8945
# Epoch 3/20
# 375/375 [==============================] - 8s 21ms/step - loss: 0.4078 - accuracy: 0.8916 - val_loss: 0.3502 - val_accuracy: 0.9065
# Epoch 4/20
# 375/375 [==============================] - 7s 20ms/step - loss: 0.3564 - accuracy: 0.9019 - val_loss: 0.3179 - val_accuracy: 0.9118
# Epoch 5/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3261 - accuracy: 0.9095 - val_loss: 0.2955 - val_accuracy: 0.9183
# Epoch 6/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3048 - accuracy: 0.9139 - val_loss: 0.2809 - val_accuracy: 0.9223
# Epoch 7/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2880 - accuracy: 0.9186 - val_loss: 0.2660 - val_accuracy: 0.9262
# Epoch 8/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2735 - accuracy: 0.9229 - val_loss: 0.2561 - val_accuracy: 0.9297
# Epoch 9/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2613 - accuracy: 0.9260 - val_loss: 0.2444 - val_accuracy: 0.9323
# Epoch 10/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2503 - accuracy: 0.9287 - val_loss: 0.2387 - val_accuracy: 0.9325
# Epoch 11/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2405 - accuracy: 0.9317 - val_loss: 0.2285 - val_accuracy: 0.9373
# Epoch 12/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2313 - accuracy: 0.9347 - val_loss: 0.2213 - val_accuracy: 0.9387
# Epoch 13/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2229 - accuracy: 0.9366 - val_loss: 0.2141 - val_accuracy: 0.9412
# Epoch 14/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2154 - accuracy: 0.9392 - val_loss: 0.2085 - val_accuracy: 0.9416
# Epoch 15/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.2080 - accuracy: 0.9415 - val_loss: 0.2025 - val_accuracy: 0.9445
# Epoch 16/20
# 375/375 [==============================] - 7s 20ms/step - loss: 0.2015 - accuracy: 0.9426 - val_loss: 0.1963 - val_accuracy: 0.9462
# Epoch 17/20
# 375/375 [==============================] - 8s 21ms/step - loss: 0.1951 - accuracy: 0.9444 - val_loss: 0.1912 - val_accuracy: 0.9477
# Epoch 18/20
# 375/375 [==============================] - 7s 17ms/step - loss: 0.1893 - accuracy: 0.9464 - val_loss: 0.1876 - val_accuracy: 0.9488
# Epoch 19/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1839 - accuracy: 0.9477 - val_loss: 0.1824 - val_accuracy: 0.9500
# Epoch 20/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1784 - accuracy: 0.9490 - val_loss: 0.1783 - val_accuracy: 0.9499
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1784 - accuracy: 0.9483
# Updated Parameter Run 3: 'N_HIDDEN' = 256
# Test score: 0.1784035712480545
# Test accuracy: 0.9483000636100769

# %%
np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # of number of outputs = number digits
OPTIMIZER = SGD() # optimizer
N_HIDDEN = 512
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in sets 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test,
                       Y_test,
                       verbose=VERBOSE)

print("Updated Parameter Run 4: 'N_HIDDEN' =", N_HIDDEN)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 512)               401920
#
#  activation_25 (Activation)  (None, 512)               0
#
#  dense_26 (Dense)            (None, 512)               262656
#
#  activation_26 (Activation)  (None, 512)               0
#
#  dense_27 (Dense)            (None, 10)                5130
#
#  activation_27 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
#  11/375 [..............................] - ETA: 4s - loss: 2.2943 - accuracy: 0.1101
# 2023-03-11 14:38:24.856993: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - ETA: 0s - loss: 1.2184 - accuracy: 0.7354
# 2023-03-11 14:38:28.446391: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 5s 12ms/step - loss: 1.2184 - accuracy: 0.7354 - val_loss: 0.5905 - val_accuracy: 0.8692
# Epoch 2/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.5028 - accuracy: 0.8760 - val_loss: 0.3975 - val_accuracy: 0.8949
# Epoch 3/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3923 - accuracy: 0.8949 - val_loss: 0.3395 - val_accuracy: 0.9058
# Epoch 4/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.3459 - accuracy: 0.9044 - val_loss: 0.3098 - val_accuracy: 0.9121
# Epoch 5/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3180 - accuracy: 0.9114 - val_loss: 0.2893 - val_accuracy: 0.9172
# Epoch 6/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2970 - accuracy: 0.9168 - val_loss: 0.2710 - val_accuracy: 0.9220
# Epoch 7/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2804 - accuracy: 0.9212 - val_loss: 0.2600 - val_accuracy: 0.9268
# Epoch 8/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2666 - accuracy: 0.9248 - val_loss: 0.2471 - val_accuracy: 0.9293
# Epoch 9/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2545 - accuracy: 0.9280 - val_loss: 0.2369 - val_accuracy: 0.9320
# Epoch 10/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2437 - accuracy: 0.9311 - val_loss: 0.2277 - val_accuracy: 0.9346
# Epoch 11/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2338 - accuracy: 0.9348 - val_loss: 0.2216 - val_accuracy: 0.9362
# Epoch 12/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2251 - accuracy: 0.9362 - val_loss: 0.2141 - val_accuracy: 0.9391
# Epoch 13/20
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2168 - accuracy: 0.9385 - val_loss: 0.2094 - val_accuracy: 0.9399
# Epoch 14/20
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2091 - accuracy: 0.9408 - val_loss: 0.2017 - val_accuracy: 0.9419
# Epoch 15/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2021 - accuracy: 0.9427 - val_loss: 0.1950 - val_accuracy: 0.9439
# Epoch 16/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1954 - accuracy: 0.9446 - val_loss: 0.1896 - val_accuracy: 0.9450
# Epoch 17/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1890 - accuracy: 0.9460 - val_loss: 0.1848 - val_accuracy: 0.9477
# Epoch 18/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1831 - accuracy: 0.9483 - val_loss: 0.1816 - val_accuracy: 0.9482
# Epoch 19/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1775 - accuracy: 0.9496 - val_loss: 0.1761 - val_accuracy: 0.9505
# Epoch 20/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1724 - accuracy: 0.9510 - val_loss: 0.1722 - val_accuracy: 0.9512
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1724 - accuracy: 0.9519
# Updated Parameter Run 4: 'N_HIDDEN' = 512
# Test score: 0.17238231003284454
# Test accuracy: 0.951900064945221

# %%
np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # of number of outputs = number digits
OPTIMIZER = SGD() # optimizer
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION

# data: shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in sets 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test,
                       Y_test,
                       verbose=VERBOSE)

print("Updated Parameter Run 5: 'N_HIDDEN' =", N_HIDDEN)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 1024)              803840
#
#  activation_28 (Activation)  (None, 1024)              0
#
#  dense_29 (Dense)            (None, 1024)              1049600
#
#  activation_29 (Activation)  (None, 1024)              0
#
#  dense_30 (Dense)            (None, 10)                10250
#
#  activation_30 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 1,863,690
# Trainable params: 1,863,690
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2023-03-11 14:40:37.286986: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 373/375 [============================>.] - ETA: 0s - loss: 1.1901 - accuracy: 0.7531
# 2023-03-11 14:40:41.763906: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 6s 14ms/step - loss: 1.1870 - accuracy: 0.7536 - val_loss: 0.5736 - val_accuracy: 0.8697
# Epoch 2/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.4867 - accuracy: 0.8797 - val_loss: 0.3890 - val_accuracy: 0.9001
# Epoch 3/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3786 - accuracy: 0.8989 - val_loss: 0.3321 - val_accuracy: 0.9095
# Epoch 4/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.3327 - accuracy: 0.9079 - val_loss: 0.3013 - val_accuracy: 0.9145
# Epoch 5/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.3048 - accuracy: 0.9153 - val_loss: 0.2806 - val_accuracy: 0.9201
# Epoch 6/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2845 - accuracy: 0.9195 - val_loss: 0.2648 - val_accuracy: 0.9243
# Epoch 7/20
# 375/375 [==============================] - 6s 15ms/step - loss: 0.2683 - accuracy: 0.9249 - val_loss: 0.2523 - val_accuracy: 0.9283
# Epoch 8/20
# 375/375 [==============================] - 6s 17ms/step - loss: 0.2548 - accuracy: 0.9280 - val_loss: 0.2425 - val_accuracy: 0.9321
# Epoch 9/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.2431 - accuracy: 0.9316 - val_loss: 0.2315 - val_accuracy: 0.9336
# Epoch 10/20
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2324 - accuracy: 0.9351 - val_loss: 0.2235 - val_accuracy: 0.9354
# Epoch 11/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2230 - accuracy: 0.9373 - val_loss: 0.2178 - val_accuracy: 0.9365
# Epoch 12/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2143 - accuracy: 0.9397 - val_loss: 0.2090 - val_accuracy: 0.9412
# Epoch 13/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2060 - accuracy: 0.9421 - val_loss: 0.2016 - val_accuracy: 0.9433
# Epoch 14/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.1988 - accuracy: 0.9441 - val_loss: 0.1958 - val_accuracy: 0.9459
# Epoch 15/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.1919 - accuracy: 0.9460 - val_loss: 0.1899 - val_accuracy: 0.9478
# Epoch 16/20
# 375/375 [==============================] - 7s 20ms/step - loss: 0.1853 - accuracy: 0.9482 - val_loss: 0.1864 - val_accuracy: 0.9474
# Epoch 17/20
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1792 - accuracy: 0.9495 - val_loss: 0.1798 - val_accuracy: 0.9499
# Epoch 18/20
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1733 - accuracy: 0.9510 - val_loss: 0.1743 - val_accuracy: 0.9520
# Epoch 19/20
# 375/375 [==============================] - 5s 13ms/step - loss: 0.1678 - accuracy: 0.9525 - val_loss: 0.1706 - val_accuracy: 0.9540
# Epoch 20/20
# 375/375 [==============================] - 8s 21ms/step - loss: 0.1624 - accuracy: 0.9541 - val_loss: 0.1668 - val_accuracy: 0.9541
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1645 - accuracy: 0.9523
# Updated Parameter Run 5: 'N_HIDDEN' = 1024
# Test score: 0.16450047492980957
# Test accuracy: 0.9523000717163086

# %% [markdown]
# # Results
#
# ## Accuracy rates for different `N_HIDDEN` values
#
# | Run      | `N_HIDDEN` | Training Accuracy | Validation Accuracy | Test Accuracy |
# |:---------|-----------:|:-----------------:|:-------------------:|:-------------:|
# | Original |        128 |      0.9441       |       0.9453        |    0.9439     |
# | 1        |          1 |      0.3006       |       0.2964        |    0.2966     |
# | 2        |         64 |      0.9381       |       0.9411        |    0.9401     |
# | 3        |        256 |      0.9490       |       0.9499        |    0.9483     |
# | 4        |        512 |      0.9510       |       0.9512        |    0.9519     |
# | 5        |       1024 |      0.9451       |       0.9541        |    0.9523     |
#
# ## Analysis
#
# The accuracy rate for the model would go up or down in relation to the value for `N_HIDDEN` going up or down.  In this model, the value for `N_HIDDEN` represents the number of hidden neurons used in the model.  Decreasing that value from the original of `128` caused the accuracy to drop significantly.  At the other end, increase the value above the original resulted in an increase of the accuracy rate.  This is becuase creating a larger network of neurons increases the overall capacity and ability to learn from larger sets.

# %%
np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # of number of outputs = number digits
OPTIMIZER = Adam() # optimizer
N_HIDDEN = 1024
VALIDATION_SPLIT=0.2 # how much TRAIN is reserved for VALIDATION
DROPOUT = 0.3

# data: shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#X_train is 60000 rows of 28x28 values --> reshaped in sets 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# M_HIDDEN hidden layers
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer=OPTIMIZER,
              metrics=['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)
score = model.evaluate(X_test,
                       Y_test,
                       verbose=VERBOSE)

print("Optimal Run:")
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_46 (Dense)            (None, 1024)              803840
#
#  activation_46 (Activation)  (None, 1024)              0
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_47 (Dense)            (None, 1024)              1049600
#
#  activation_47 (Activation)  (None, 1024)              0
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_48 (Dense)            (None, 10)                10250
#
#  activation_48 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 1,863,690
# Trainable params: 1,863,690
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-03-11 16:45:08.444984: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 373/375 [============================>.] - ETA: 0s - loss: 0.2547 - accuracy: 0.9219
# 2023-03-11 16:45:12.962296: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 375/375 [==============================] - 6s 14ms/step - loss: 0.2539 - accuracy: 0.9222 - val_loss: 0.1140 - val_accuracy: 0.9641
# Epoch 2/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.1103 - accuracy: 0.9659 - val_loss: 0.0957 - val_accuracy: 0.9703
# Epoch 3/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0772 - accuracy: 0.9757 - val_loss: 0.0805 - val_accuracy: 0.9765
# Epoch 4/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0595 - accuracy: 0.9819 - val_loss: 0.0820 - val_accuracy: 0.9758
# Epoch 5/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0517 - accuracy: 0.9839 - val_loss: 0.0778 - val_accuracy: 0.9776
# Epoch 6/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0429 - accuracy: 0.9867 - val_loss: 0.0808 - val_accuracy: 0.9778
# Epoch 7/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0392 - accuracy: 0.9866 - val_loss: 0.1117 - val_accuracy: 0.9732
# Epoch 8/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0372 - accuracy: 0.9880 - val_loss: 0.0938 - val_accuracy: 0.9773
# Epoch 9/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0320 - accuracy: 0.9893 - val_loss: 0.0987 - val_accuracy: 0.9779
# Epoch 10/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0303 - accuracy: 0.9898 - val_loss: 0.0979 - val_accuracy: 0.9771
# Epoch 11/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0289 - accuracy: 0.9906 - val_loss: 0.0983 - val_accuracy: 0.9772
# Epoch 12/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0953 - val_accuracy: 0.9777
# Epoch 13/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 0.1002 - val_accuracy: 0.9781
# Epoch 14/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 0.1088 - val_accuracy: 0.9787
# Epoch 15/50
# 375/375 [==============================] - 4s 12ms/step - loss: 0.0273 - accuracy: 0.9918 - val_loss: 0.0914 - val_accuracy: 0.9794
# Epoch 16/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.1056 - val_accuracy: 0.9792
# Epoch 17/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0218 - accuracy: 0.9933 - val_loss: 0.0974 - val_accuracy: 0.9804
# Epoch 18/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.0989 - val_accuracy: 0.9812
# Epoch 19/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0202 - accuracy: 0.9936 - val_loss: 0.1207 - val_accuracy: 0.9782
# Epoch 20/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0231 - accuracy: 0.9934 - val_loss: 0.0987 - val_accuracy: 0.9817
# Epoch 21/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0191 - accuracy: 0.9945 - val_loss: 0.1098 - val_accuracy: 0.9799
# Epoch 22/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0174 - accuracy: 0.9948 - val_loss: 0.0995 - val_accuracy: 0.9812
# Epoch 23/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.1097 - val_accuracy: 0.9807
# Epoch 24/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.0981 - val_accuracy: 0.9818
# Epoch 25/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0998 - val_accuracy: 0.9826
# Epoch 26/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.1286 - val_accuracy: 0.9797
# Epoch 27/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.1172 - val_accuracy: 0.9807
# Epoch 28/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.1082 - val_accuracy: 0.9822
# Epoch 29/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.1091 - val_accuracy: 0.9822
# Epoch 30/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0166 - accuracy: 0.9956 - val_loss: 0.1134 - val_accuracy: 0.9820
# Epoch 31/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.1247 - val_accuracy: 0.9807
# Epoch 32/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0169 - accuracy: 0.9953 - val_loss: 0.1290 - val_accuracy: 0.9805
# Epoch 33/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.1262 - val_accuracy: 0.9806
# Epoch 34/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.1261 - val_accuracy: 0.9811
# Epoch 35/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.1226 - val_accuracy: 0.9813
# Epoch 36/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.1268 - val_accuracy: 0.9808
# Epoch 37/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0157 - accuracy: 0.9958 - val_loss: 0.1122 - val_accuracy: 0.9834
# Epoch 38/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.1159 - val_accuracy: 0.9817
# Epoch 39/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 0.1159 - val_accuracy: 0.9821
# Epoch 40/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.1386 - val_accuracy: 0.9807
# Epoch 41/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0125 - accuracy: 0.9967 - val_loss: 0.1452 - val_accuracy: 0.9814
# Epoch 42/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.1441 - val_accuracy: 0.9819
# Epoch 43/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.1388 - val_accuracy: 0.9820
# Epoch 44/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0148 - accuracy: 0.9963 - val_loss: 0.1390 - val_accuracy: 0.9822
# Epoch 45/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.1473 - val_accuracy: 0.9814
# Epoch 46/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.1451 - val_accuracy: 0.9830
# Epoch 47/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.1450 - val_accuracy: 0.9813
# Epoch 48/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0113 - accuracy: 0.9969 - val_loss: 0.1500 - val_accuracy: 0.9805
# Epoch 49/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.1379 - val_accuracy: 0.9816
# Epoch 50/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.0122 - accuracy: 0.9970 - val_loss: 0.1662 - val_accuracy: 0.9817
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1208 - accuracy: 0.9823
# Optimal Run:
# Test score: 0.12075091153383255
# Test accuracy: 0.9823000431060791
